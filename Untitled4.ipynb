# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv('house_price_test.csv')

# %%
df2=pd.read_csv('house_price_train.csv')

# %%
df1
# Out:
#     Area  Rooms   Price
# 0   2609      4  499998
# 1   2238      3  329900
# 2   4478      5  699900
# 3   1962      4  259900
# 4   1600      3  329900
# 5   1268      3  259900
# 6   3031      4  599000
# 7   1664      2  368500
# 8   1767      3  252900
# 9   3137      3  579900
# 10  4215      4  549000
# 11  1888      2  255000

# %%
df2
# Out:
#     Area  Rooms   Price
# 0   2637      3  299900
# 1   2132      4  345000
# 2   1985      4  299900
# 3   1416      2  232000
# 4   2567      4  314000
# 5   2162      4  287000
# 6   1494      3  242500
# 7   2000      3  347000
# 8   2040      4  314900
# 9   1000      1  169900
# 10  1239      3  229900
# 11  3000      4  539900
# 12  2104      3  399900
# 13  1437      3  249900
# 14  1839      2  349900
# 15  1852      4  299900
# 16  1236      3  199900
# 17  1100      3  249900
# 18  1380      3  212000
# 19  1940      4  239999
# 20  1458      3  464500
# 21  1427      3  198999
# 22   852      2  179900
# 23  1604      3  242900
# 24  1811      4  285900
# 25  2526      3  469000
# 26  3890      3  573900
# 27  1200      3  299000
# 28  1534      3  314900
# 29  2200      3  475000
# 30  2300      4  449900
# 31  1320      2  299900
# 32  1890      3  329999
# 33  1203      3  239500
# 34  2400      3  369000

# %%
df=pd.concat([df1,df2],axis=0)

# %%
df
# Out:
#     Area  Rooms   Price
# 0   2609      4  499998
# 1   2238      3  329900
# 2   4478      5  699900
# 3   1962      4  259900
# 4   1600      3  329900
# 5   1268      3  259900
# 6   3031      4  599000
# 7   1664      2  368500
# 8   1767      3  252900
# 9   3137      3  579900
# 10  4215      4  549000
# 11  1888      2  255000
# 0   2637      3  299900
# 1   2132      4  345000
# 2   1985      4  299900
# 3   1416      2  232000
# 4   2567      4  314000
# 5   2162      4  287000
# 6   1494      3  242500
# 7   2000      3  347000
# 8   2040      4  314900
# 9   1000      1  169900
# 10  1239      3  229900
# 11  3000      4  539900
# 12  2104      3  399900
# 13  1437      3  249900
# 14  1839      2  349900
# 15  1852      4  299900
# 16  1236      3  199900
# 17  1100      3  249900
# 18  1380      3  212000
# 19  1940      4  239999
# 20  1458      3  464500
# 21  1427      3  198999
# 22   852      2  179900
# 23  1604      3  242900
# 24  1811      4  285900
# 25  2526      3  469000
# 26  3890      3  573900
# 27  1200      3  299000
# 28  1534      3  314900
# 29  2200      3  475000
# 30  2300      4  449900
# 31  1320      2  299900
# 32  1890      3  329999
# 33  1203      3  239500
# 34  2400      3  369000

# %%
df.reset_index(drop=True)
# Out:
#     Area  Rooms   Price
# 0   2609      4  499998
# 1   2238      3  329900
# 2   4478      5  699900
# 3   1962      4  259900
# 4   1600      3  329900
# 5   1268      3  259900
# 6   3031      4  599000
# 7   1664      2  368500
# 8   1767      3  252900
# 9   3137      3  579900
# 10  4215      4  549000
# 11  1888      2  255000
# 12  2637      3  299900
# 13  2132      4  345000
# 14  1985      4  299900
# 15  1416      2  232000
# 16  2567      4  314000
# 17  2162      4  287000
# 18  1494      3  242500
# 19  2000      3  347000
# 20  2040      4  314900
# 21  1000      1  169900
# 22  1239      3  229900
# 23  3000      4  539900
# 24  2104      3  399900
# 25  1437      3  249900
# 26  1839      2  349900
# 27  1852      4  299900
# 28  1236      3  199900
# 29  1100      3  249900
# 30  1380      3  212000
# 31  1940      4  239999
# 32  1458      3  464500
# 33  1427      3  198999
# 34   852      2  179900
# 35  1604      3  242900
# 36  1811      4  285900
# 37  2526      3  469000
# 38  3890      3  573900
# 39  1200      3  299000
# 40  1534      3  314900
# 41  2200      3  475000
# 42  2300      4  449900
# 43  1320      2  299900
# 44  1890      3  329999
# 45  1203      3  239500
# 46  2400      3  369000

# %%
df.describe().T
# Out:
#        count           mean            std       min       25%       50%  \
# Area    47.0    2000.680851     794.702354     852.0    1432.0    1888.0
# Rooms   47.0       3.170213       0.760982       1.0       3.0       3.0
# Price   47.0  340412.659574  125039.899586  169900.0  249900.0  299900.0
#
#             75%       max
# Area     2269.0    4478.0
# Rooms       4.0       5.0
# Price  384450.0  699900.0

# %%
df.isna().apply(pd.value_counts).T
# Out:
#        False
# Area      47
# Rooms     47
# Price     47

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(df['Area'])

# %%
X=df.drop('Price', axis=1)

# %%
X.head()
# Out:
#    Area  Rooms
# 0  2609      4
# 1  2238      3
# 2  4478      5
# 3  1962      4
# 4  1600      3

# %%
y=df['Price']

# %%
y
# Out:
# 0     499998
# 1     329900
# 2     699900
# 3     259900
# 4     329900
# 5     259900
# 6     599000
# 7     368500
# 8     252900
# 9     579900
# 10    549000
# 11    255000
# 0     299900
# 1     345000
# 2     299900
# 3     232000
# 4     314000
# 5     287000
# 6     242500
# 7     347000
# 8     314900
# 9     169900
# 10    229900
# 11    539900
# 12    399900
# 13    249900
# 14    349900
# 15    299900
# 16    199900
# 17    249900
# 18    212000
# 19    239999
# 20    464500
# 21    198999
# 22    179900
# 23    242900
# 24    285900
# 25    469000
# 26    573900
# 27    299000
# 28    314900
# 29    475000
# 30    449900
# 31    299900
# 32    329999
# 33    239500
# 34    369000
# Name: Price, dtype: int64

# %%
y=df[['Price']]

# %%
y
# Out:
#      Price
# 0   499998
# 1   329900
# 2   699900
# 3   259900
# 4   329900
# 5   259900
# 6   599000
# 7   368500
# 8   252900
# 9   579900
# 10  549000
# 11  255000
# 0   299900
# 1   345000
# 2   299900
# 3   232000
# 4   314000
# 5   287000
# 6   242500
# 7   347000
# 8   314900
# 9   169900
# 10  229900
# 11  539900
# 12  399900
# 13  249900
# 14  349900
# 15  299900
# 16  199900
# 17  249900
# 18  212000
# 19  239999
# 20  464500
# 21  198999
# 22  179900
# 23  242900
# 24  285900
# 25  469000
# 26  573900
# 27  299000
# 28  314900
# 29  475000
# 30  449900
# 31  299900
# 32  329999
# 33  239500
# 34  369000

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test,y_train,y_test= train_test_split(X,y,test_size=0.2, random_state=1)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(X_test)

# %%
pred
# Out:
# array([[348629.06813929],
#        [223757.01149752],
#        [218126.94189171],
#        [276448.68857758],
#        [675999.53675512],
#        [320458.85357216],
#        [203690.86597936],
#        [255372.01774555],
#        [218560.02416908],
#        [318044.45374319]])

# %%
print(model.coef_)
# Out:
# [[  144.36075912 -7670.9867716 ]]

# %%
print(model.intercept_)
# Out:
# [67906.9912584]

# %%
X_test.shape
# Out:
# (10, 2)

# %%
df1=pd.DataFrame({'actual price':y_test.values.flatten(), "predicted price":pred.flatten()})

# %%
df1
# Out:
#    actual price  predicted price
# 0        399900    348629.068139
# 1        229900    223757.011498
# 2        299000    218126.941892
# 3        242900    276448.688578
# 4        699900    675999.536755
# 5        259900    320458.853572
# 6        249900    203690.865979
# 7        464500    255372.017746
# 8        239500    218560.024169
# 9        349900    318044.453743

# %%
from sklearn import metrics#Accuracy
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# Mean Absolute Error: 56442.76222289073
# Mean Squared Error: 6189407312.783555
# Root Mean Squared Error: 78672.7863545175

# %%
plt.scatter(X_test, y_test,  color='gray')
plt.title('Line Of Best Fit')
plt.plot(X_test, pred, color='red', linewidth=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-37a6ed564e11> in <module>
# ----> 1 plt.scatter(X_test, y_test,  color='gray')
#       2 plt.title('Line Of Best Fit')
#       3 plt.plot(X_test, pred, color='red', linewidth=2)
#       4 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2809         verts=cbook.deprecation._deprecated_parameter,
#    2810         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2811     __ret = gca().scatter(
#    2812         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2813         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4389         y = np.ma.ravel(y)
#    4390         if x.size != y.size:
# -> 4391             raise ValueError("x and y must be the same size")
#    4392
#    4393         if s is None:
#
# ValueError: x and y must be the same size
